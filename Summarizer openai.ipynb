# %%
from openai import AzureOpenAI
from azure.identity import DefaultAzureCredential
import pandas as pd
from pyspark.sql import SparkSession

# Azure OpenAI configuration
ENDPOINT = "https://mango-bush-0a9e12903.5.azurestaticapps.net/api/v1"
API_KEY = "805387ca-461f-4cb8-af1b-e235da89e5a8"
API_VERSION = "2024-02-01"
MODEL_NAME = "gpt-4o-mini-kenya-hack"

def get_data_from_lakehouse():
    """Retrieve data from Fabric Lakehouse using Delta path"""
    try:
        # Create Spark session
        spark = SparkSession.builder \
            .appName("LakehouseQuery") \
            .getOrCreate()
        
        # Read data from Delta table using the lakehouse path
        #df = spark.read.format("delta").load("/lakehouse/default/tables/SilverTable")
        df = spark.sql("select * from SilverTable where Case_Number not in (select Case_Number from casesummaries)")

        # Convert to pandas DataFrame (if needed)
        pandas_df = df.limit(10).toPandas()  # Get top 10 rows
        
        return pandas_df
    
    except Exception as e:
        print(f"Error connecting to Lakehouse: {str(e)}")
        return None

def generate_summaries(df, text_column):
    """Generate summaries for each row using Azure OpenAI"""
    client = AzureOpenAI(
        azure_endpoint=ENDPOINT,
        api_key=API_KEY,
        api_version=API_VERSION,
    )
    
    summaries = []
    
    for index, row in df.iterrows():
        prompt = f"""
        Analyze the following case data and generate a concise summary:
        
        Case ID: {row['Case_Number']}
        Details: {row[text_column]}
        
        Please provide a 2-3 sentence summary highlighting key points.
        """
        
        try:
            completion = client.chat.completions.create(
                model=MODEL_NAME,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant that summarizes case data."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3  # Lower temperature for more factual responses
            )
            
            summary = completion.choices[0].message.content
            summaries.append(summary)
            
        except Exception as e:
            print(f"Error generating summary for Case ID {row['Case_Number']}: {str(e)}")
            summaries.append("Summary unavailable")
    
    return summaries


def save_to_lakehouse_table(df, table_name="CaseSummaries"):
    """Save DataFrame to a new table in the Lakehouse using Spark SQL"""
    try:
        # Create Spark session if not already exists
        spark = SparkSession.builder.getOrCreate()
        
        # Convert pandas DataFrame to Spark DataFrame
        spark_df = spark.createDataFrame(df)
        
        # Save as a new table in the Lakehouse
        spark_df.write.mode("append").format("delta").saveAsTable(table_name)
        
        print(f"Successfully saved data to table: {table_name}")
        
    except Exception as e:
        print(f"Error saving to Lakehouse table: {str(e)}")


def main():
    # Step 1: Get data from Lakehouse
    df = get_data_from_lakehouse()
    
    if df is None or df.empty:
        print("No data retrieved from Lakehouse.")
        return
    
    # Step 2: Specify which column contains the text to summarize
    text_column = "Ruling"  # Replace with your actual column name
    
    # Step 3: Generate summaries
    print("Generating summaries...")
    df['Summary'] = generate_summaries(df, text_column)
    
    # Step 4: Output or save results
    print("\nGenerated Summaries:")
    for _, row in df.iterrows():
        print(f"\nCase ID: {row['Case_Number']}")
        print(f"Summary: {row['Summary']}")
        print("-" * 50)
    
    # Optionally save to CSV
    # df.to_csv('case_summaries.csv', index=False)

    save_to_lakehouse_table(df)

if __name__ == "__main__":
    main()
# Out:
# StatementMeta(, c39909b1-e739-4918-9861-e084cb848334, 5, Finished, Available, Finished)
# Generating summaries...
# Error generating summary for Case ID Criminal Case E012 of 2024: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 50 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}
# Error generating summary for Case ID Civil Appeal 275 of 2019: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 53 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}
# Error generating summary for Case ID Criminal Application E007 of 2025: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 46 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}
# Error generating summary for Case ID Criminal Application E018 of 2024: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-02-01 have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 44 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit. For Free Account customers, upgrade to Pay as you Go here: https://aka.ms/429TrialUpgrade.'}}
#
# Generated Summaries:
#
# Case ID: Miscellaneous Criminal Application E004 of 2023
# Summary: In the case Miscellaneous Criminal Application E004 of 2023, the application to appeal out of time has been granted, allowing the applicant to file the intended appeal within 30 days. Failure to do so will result in the lapse of leave. Notices are to be issued to both the respondent and the applicant, and the matter is marked as closed.
# --------------------------------------------------
#
# Case ID: Criminal Case E047 of 2023
# Summary: In Criminal Case E047 of 2023, accused John Sila Manza and Redempta B. Nthenya John were charged with the murder of three-year-old Stephanie Ninsa, which occurred on August 19, 2022. The court found that the prosecution presented sufficient evidence to establish a prima facie case, leading to the decision that the accused must enter a defense. Consequently, the court ordered that the accused be placed on their defense to answer the charges.
# --------------------------------------------------
#
# Case ID: Criminal Case E009 of 2025
# Summary: In Criminal Case E009 of 2025, the court ruled on an application for bond by the Accused, charged with murder. Despite opposition from the prosecution and the victim's family, the court granted bail of Kshs. 500,000 with one surety, citing that there were no compelling reasons to deny bond, particularly as there was no threat to the Accused's life from the community. The decision considered the Accused's social exclusion and the nature of the crime but ultimately upheld his constitutional right to bail.
# --------------------------------------------------
#
# Case ID: Criminal Case 47 of 2019
# Summary: In Criminal Case 47 of 2019, Kizito Indeche was charged with the murder of Peter Kibathi, but the prosecution failed to prove his guilt beyond a reasonable doubt due to a lack of eyewitness testimony and insufficient investigation. The court noted that the only evidence presented did not convincingly link Indeche to the crime, leading to his acquittal. Consequently, the bond/bail security deposited on his behalf was discharged.
# --------------------------------------------------
#
# Case ID: Criminal Case E005 of 2025
# Summary: In Criminal Case E005 of 2025, the court denied the Accused's application for bail due to ongoing hostility from the victim's family and community tensions, which pose a risk to the Accused's safety if released. The pre-bail report and evidence indicated that the Accused had previously been assaulted by the public, and the court deemed it necessary to prioritize community safety and peace. The Accused may revisit the bail application after the first hearing, when tensions are expected to have lessened.
# --------------------------------------------------
#
# Case ID: Criminal Case E012 of 2024
# Summary: Summary unavailable
# --------------------------------------------------
#
# Case ID: Civil Appeal 275 of 2019
# Summary: Summary unavailable
# --------------------------------------------------
#
# Case ID: Criminal Application E009 of 2025
# Summary: In Criminal Application E009 of 2025, the applicant seeks leave to appeal out of time against his conviction and life sentence for robbery with violence and rape, originally decided by the Naivasha High Court in 2018. Despite a seven-year delay in filing the appeal, the court granted the application, emphasizing the importance of justice over procedural delays, and directed the applicant to file his notice of appeal within 14 days and the record of appeal within 30 days. The prosecution did not oppose the application due to the lengthy nature of the sentence.
# --------------------------------------------------
#
# Case ID: Criminal Application E007 of 2025
# Summary: Summary unavailable
# --------------------------------------------------
#
# Case ID: Criminal Application E018 of 2024
# Summary: Summary unavailable
# --------------------------------------------------
# Successfully saved data to table: CaseSummaries
